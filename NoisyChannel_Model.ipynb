# %% [markdown]
# <a href="https://colab.research.google.com/github/AYA0HASSAN/AutoCorrect/blob/main/NoisyChannel_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import numpy as np
import random
import re
import string
import sys
import pandas as pd
from collections import Counter
corpus = open(r"F:\7sabat\NLP\datasetTRY.txt").read()

# %% [markdown]
# # Get Words to make Vocabulary

# %%
def get_all_words(corpus):
    return re.findall(r'\w+',corpus.lower())

# %%
Words = Counter(get_all_words(corpus))

# %% [markdown]
# # calculate probability of each word

# %%
def probability(word):
    N = sum(Words.values())
    return Words[word]/N

# %%
def known(words):
    revelant = []
    for w in words:
        if w in Words:
            revelant.append(w)
    return revelant

# %% [markdown]
# # Minimun Edit Distance of Only one change

# %%
def edits_1(word):
    letters_english = 'abcdefghijklmnopqrstuvwxyz'
    letters_arbic = 'ابتثجحخدذرزسشصضطظعغفقكلمنهويةىء'
    splits = [(word[:i],word[i:]) for i in range(len(word)+1)]
    deletes = [left + right[1:] for left,right in splits if right]
    inserts = [left + center + right for left , right in splits for center in letters_english]
    replaces = [left + center + right[1:] for left , right in splits if right for center in letters_english]
    transposes = [left + right[1] + right[0] +right[2:] for left , right in splits if len(right)>1]
    return set(deletes + inserts + replaces + transposes)

# %% [markdown]
# # Minimun Edit Distance of Two changes

# %%
def edits_2(word):
    for edit1 in edits_1(word):
        for edit2 in edits_1(edit1):
            return edit2

# %% [markdown]
# # Returning Candidates for the misspelled word

# %%
def candidates(word):
    return ( known(edits_1(word)) or known(edits_2(word)) or known([word]) or [word])

# %%
def best_correction(word):
    return max(candidates(word),key = probability)

# %%
len(Words)
# Out:
# 968

# %%
max(Words , key=probability)
# Out:
# 'presbyterian'

# %%
probability('presbyterian')
# Out:
# 0.002034587995930824

# %%
known(edits_1('wen'))
# Out:
# ['won', 'wan']

# %%
candidates('wen')
# Out:
# ['won', 'wan']

# %%
best_correction('deu')
# Out:
# 'due'

# %% [markdown]
# # Making Combinations for N-Gram Model

# %%
def creat_Ngram(n,words):
    words_len = len(words)
    Ngram_list = []
    for idx , word in enumerate(words):
        single_Ngram = []
        for i in range(n):
            if(idx+n <= words_len):
                single_Ngram.append(words[idx+i])
        if(len(single_Ngram)==n):
            Ngram_list.append(tuple(single_Ngram))
    return Ngram_list

# %% [markdown]
# # Calculate Count of Uni-Grams and Bi-Grams

# %%
def get_counts(N):
    words = get_all_words(corpus)
    Ngram = creat_Ngram(N,words)
    Ngram_count = Counter(Ngram)
    return Ngram_count

# %%
get_counts(2)
# Out:
# Counter({('nevada', 'nevade'): 1,
#          ('nevade', 'presbyterian'): 1,
#          ('presbyterian', 'presbyterian'): 1,
#          ('presbyterian', 'rsx'): 1,
#          ('rsx', 'rsx'): 1,
#          ('rsx', 'stephen'): 1,
#          ('stephen', 'steffen'): 1,
#          ('steffen', 'susan'): 1,
#          ('susan', 'susan'): 1,
#          ('susan', 'ability'): 1,
#          ('ability', 'abilitey'): 1,
#          ('abilitey', 'about'): 1,
#          ('about', 'abouy'): 1,
#          ('abouy', 'absorption'): 1,
#          ('absorption', 'absorbtion'): 1,
#          ('absorbtion', 'accidentally'): 1,
#          ('accidentally', 'accidently'): 1,
#          ('accidently', 'accommodate'): 1,
#          ('accommodate', 'accomodate'): 1,
#          ('accomodate', 'acommadate'): 1,
#          ('acommadate', 'accord'): 1,
#          ('accord', 'acord'): 1,
#          ('acord', 'acquaintance'): 1,
#          ('acquaintance', 'aquantance'): 1,
#          ('aquantance', 'acquire'): 1,
#          ('acquire', 'equire'): 1,
#          ('equire', 'adultery'): 1,
#          ('adultery', 'adultry'): 1,
#          ('adultry', 'aggressive'): 1,
#          ('aggressive', 'aggresive'): 1,
#          ('aggresive', 'alcohol'): 1,
#          ('alcohol', 'alchohol'): 1,
#          ('alchohol', 'alcoholic'): 1,
#          ('alcoholic', 'alchoholic'): 1,
#          ('alchoholic', 'alive'): 1,
#          ('alive', 'allieve'): 1,
#          ('allieve', 'all_right'): 1,
#          ('all_right', 'alright'): 1,
#          ('alright', 'amateur'): 1,
#          ('amateur', 'amature'): 1,
#          ('amature', 'ambivalent'): 1,
#          ('ambivalent', 'ambivilant'): 1,
#          ('ambivilant', 'amorphous'): 1,
#          ('amorphous', 'amourfous'): 1,
#          ('amourfous', 'amplification'): 1,
#          ('amplification', 'amification'): 1,
#          ('amification', 'anatomy'): 1,
#          ('anatomy', 'anonomy'): 1,
#          ('anonomy', 'anotomy'): 1,
#          ('anotomy', 'announce'): 1,
#          ('announce', 'annuncio'): 1,
#          ('annuncio', 'announcement'): 1,
#          ('announcement', 'annonsment'): 1,
#          ('annonsment', 'anoint'): 1,
#          ('anoint', 'annoint'): 1,
#          ('annoint', 'anonymous'): 1,
#          ('anonymous', 'anynomous'): 1,
#          ('anynomous', 'appreciate'): 1,
#          ('appreciate', 'appresteate'): 1,
#          ('appresteate', 'appreciated'): 1,
#          ('appreciated', 'appreceiated'): 1,
#          ('appreceiated', 'archetype'): 1,
#          ('archetype', 'archeype'): 1,
#          ('archeype', 'architecture'): 1,
#          ('architecture', 'aratictature'): 1,
#          ('aratictature', 'aricticure'): 1,
#          ('aricticure', 'arctic'): 1,
#          ('arctic', 'artic'): 1,
#          ('artic', 'asterisk'): 1,
#          ('asterisk', 'asterick'): 1,
#          ('asterick', 'asymmetric'): 1,
#          ('asymmetric', 'asymetric'): 1,
#          ('asymetric', 'asymptote'): 1,
#          ('asymptote', 'asentote'): 1,
#          ('asentote', 'at'): 1,
#          ('at', 'ast'): 1,
#          ('ast', 'attentively'): 1,
#          ('attentively', 'atentively'): 1,
#          ('atentively', 'automatically'): 1,
#          ('automatically', 'autoamlly'): 1,
#          ('autoamlly', 'bankrupt'): 1,
#          ('bankrupt', 'bankrot'): 1,
#          ('bankrot', 'basically'): 1,
#          ('basically', 'basicly'): 1,
#          ('basicly', 'battalion'): 1,
#          ('battalion', 'batallion'): 1,
#          ('batallion', 'beginning'): 1,
#          ('beginning', 'beggining'): 1,
#          ('beggining', 'beging'): 1,
#          ('beging', 'bigginging'): 1,
#          ('bigginging', 'behavior'): 1,
#          ('behavior', 'behaviour'): 1,
#          ('behaviour', 'behaviour'): 1,
#          ('behaviour', 'behavior'): 1,
#          ('behavior', 'believe'): 1,
#          ('believe', 'beleive'): 1,
#          ('beleive', 'belive'): 1,
#          ('belive', 'benefits'): 1,
#          ('benefits', 'benidifs'): 1,
#          ('benidifs', 'better'): 1,
#          ('better', 'metter'): 1,
#          ('metter', 'bleat'): 1,
#          ('bleat', 'blait'): 1,
#          ('blait', 'boycott'): 1,
#          ('boycott', 'boygot'): 1,
#          ('boygot', 'broccoli'): 1,
#          ('broccoli', 'brocolli'): 1,
#          ('brocolli', 'browse'): 1,
#          ('browse', 'bbrose'): 1,
#          ('bbrose', 'buoyant'): 1,
#          ('buoyant', 'bouyant'): 1,
#          ('bouyant', 'bureau'): 1,
#          ('bureau', 'beauro'): 1,
#          ('beauro', 'bureaucracy'): 1,
#          ('bureaucracy', 'beaurocracy'): 1,
#          ('beaurocracy', 'buracracy'): 1,
#          ('buracracy', 'burracracy'): 1,
#          ('burracracy', 'bush'): 1,
#          ('bush', 'buch'): 1,
#          ('buch', 'butter'): 1,
#          ('butter', 'buder'): 1,
#          ('buder', 'budr'): 1,
#          ('budr', 'budter'): 1,
#          ('budter', 'button'): 1,
#          ('button', 'buton'): 1,
#          ('buton', 'by_by'): 1,
#          ('by_by', 'byby'): 1,
#          ('byby', 'caller'): 1,
#          ('caller', 'cauler'): 1,
#          ('cauler', 'came'): 1,
#          ('came', 'gamne'): 1,
#          ('gamne', 'caveats'): 1,
#          ('caveats', 'cravets'): 1,
#          ('cravets', 'cemetery'): 1,
#          ('cemetery', 'cemetary'): 1,
#          ('cemetary', 'changing'): 1,
#          ('changing', 'changeing'): 1,
#          ('changeing', 'cheat'): 1,
#          ('cheat', 'cheet'): 1,
#          ('cheet', 'circle'): 1,
#          ('circle', 'cicle'): 1,
#          ('cicle', 'circue'): 1,
#          ('circue', 'circumstances'): 1,
#          ('circumstances', 'circumstaces'): 1,
#          ('circumstaces', 'club'): 1,
#          ('club', 'clob'): 1,
#          ('clob', 'cockamamie'): 1,
#          ('cockamamie', 'cocamena'): 1,
#          ('cocamena', 'colleague'): 1,
#          ('colleague', 'colleaque'): 1,
#          ('colleaque', 'colloquialism'): 1,
#          ('colloquialism', 'colloquilism'): 1,
#          ('colloquilism', 'colon'): 1,
#          ('colon', 'coaln'): 1,
#          ('coaln', 'column'): 1,
#          ('column', 'columne'): 1,
#          ('columne', 'combo'): 1,
#          ('combo', 'cumba'): 1,
#          ('cumba', 'commercials'): 1,
#          ('commercials', 'commerciasl'): 1,
#          ('commerciasl', 'commitment'): 1,
#          ('commitment', 'comitmment'): 1,
#          ('comitmment', 'comittmen'): 1,
#          ('comittmen', 'comittmend'): 1,
#          ('comittmend', 'committed'): 1,
#          ('committed', 'commited'): 1,
#          ('commited', 'committee'): 1,
#          ('committee', 'comitte'): 1,
#          ('comitte', 'commitee'): 1,
#          ('commitee', 'companies'): 1,
#          ('companies', 'companys'): 1,
#          ('companys', 'compiler'): 1,
#          ('compiler', 'comiler'): 1,
#          ('comiler', 'complicated'): 1,
#          ('complicated', 'compicated'): 1,
#          ('compicated', 'computer'): 1,
#          ('computer', 'comupter'): 1,
#          ('comupter', 'congratulations'): 1,
#          ('congratulations', 'congradulations'): 1,
#          ('congradulations', 'consensus'): 1,
#          ('consensus', 'concensus'): 1,
#          ('concensus', 'consistent'): 1,
#          ('consistent', 'consident'): 1,
#          ('consident', 'consonant'): 1,
#          ('consonant', 'consident'): 1,
#          ('consident', 'constant'): 1,
#          ('constant', 'contast'): 1,
#          ('contast', 'contastant'): 1,
#          ('contastant', 'continue'): 1,
#          ('continue', 'contunie'): 1,
#          ('contunie', 'contribution'): 1,
#          ('contribution', 'conibation'): 1,
#          ('conibation', 'coolly'): 1,
#          ('coolly', 'cooly'): 1,
#          ('cooly', 'coping'): 1,
#          ('coping', 'copping'): 1,
#          ('copping', 'cosmopolitan'): 1,
#          ('cosmopolitan', 'cosmoplyton'): 1,
#          ('cosmoplyton', 'court'): 1,
#          ('court', 'courst'): 1,
#          ('courst', 'crazy'): 1,
#          ('crazy', 'crasy'): 1,
#          ('crasy', 'credibility'): 1,
#          ('credibility', 'credetability'): 1,
#          ('credetability', 'critique'): 1,
#          ('critique', 'criqitue'): 1,
#          ('criqitue', 'ctitique'): 1,
#          ('ctitique', 'croak'): 1,
#          ('croak', 'croke'): 1,
#          ('croke', 'crucified'): 1,
#          ('crucified', 'crusifed'): 1,
#          ('crusifed', 'crucifixion'): 1,
#          ('crucifixion', 'crucifiction'): 1,
#          ('crucifiction', 'customization'): 1,
#          ('customization', 'custamisation'): 1,
#          ('custamisation', 'daily'): 1,
#          ('daily', 'daly'): 1,
#          ('daly', 'dangerous'): 1,
#          ('dangerous', 'danguages'): 1,
#          ('danguages', 'dangle'): 1,
#          ('dangle', 'dongle'): 1,
#          ('dongle', 'decision'): 1,
#          ('decision', 'disition'): 1,
#          ('disition', 'defence'): 1,
#          ('defence', 'defense'): 1,
#          ('defense', 'defense'): 1,
#          ('defense', 'defence'): 1,
#          ('defence', 'defiantly'): 1,
#          ('defiantly', 'defenly'): 1,
#          ('defenly', 'definite'): 1,
#          ('definite', 'definate'): 1,
#          ('definate', 'definitely'): 1,
#          ('definitely', 'definately'): 1,
#          ('definately', 'deities'): 1,
#          ('deities', 'dieties'): 1,
#          ('dieties', 'dependable'): 1,
#          ('dependable', 'dependeble'): 1,
#          ('dependeble', 'description'): 1,
#          ('description', 'descrption'): 1,
#          ('descrption', 'descrptn'): 1,
#          ('descrptn', 'desiccate'): 1,
#          ('desiccate', 'dessicate'): 1,
#          ('dessicate', 'despair'): 1,
#          ('despair', 'dispair'): 1,
#          ('dispair', 'desperate'): 1,
#          ('desperate', 'desparate'): 1,
#          ('desparate', 'destroy'): 1,
#          ('destroy', 'distroy'): 1,
#          ('distroy', 'development'): 1,
#          ('development', 'developement'): 1,
#          ('developement', 'develpond'): 1,
#          ('develpond', 'developments'): 1,
#          ('developments', 'develepment'): 1,
#          ('develepment', 'dictionary'): 1,
#          ('dictionary', 'ductioneery'): 1,
#          ('ductioneery', 'dinosaur'): 1,
#          ('dinosaur', 'dinasaur'): 1,
#          ('dinasaur', 'dinasour'): 1,
#          ('dinasour', 'directly'): 1,
#          ('directly', 'direcyly'): 1,
#          ('direcyly', 'disagree'): 1,
#          ('disagree', 'diagree'): 1,
#          ('diagree', 'discuss'): 1,
#          ('discuss', 'discuess'): 1,
#          ('discuess', 'discussion'): 1,
#          ('discussion', 'disssicion'): 1,
#          ('disssicion', 'dissect'): 1,
#          ('dissect', 'disect'): 1,
#          ('disect', 'dissipate'): 1,
#          ('dissipate', 'disippate'): 1,
#          ('disippate', 'distant'): 1,
#          ('distant', 'destint'): 1,
#          ('destint', 'distort'): 1,
#          ('distort', 'distart'): 1,
#          ('distart', 'distract'): 1,
#          ('distract', 'distarct'): 1,
#          ('distarct', 'divulge'): 1,
#          ('divulge', 'devulge'): 1,
#          ('devulge', 'documentation'): 1,
#          ('documentation', 'documtations'): 1,
#          ('documtations', 'dog'): 1,
#          ('dog', 'dag'): 1,
#          ('dag', 'doog'): 1,
#          ('doog', 'download'): 1,
#          ('download', 'doenload'): 1,
#          ('doenload', 'draft'): 1,
#          ('draft', 'deaft'): 1,
#          ('deaft', 'dramatically'): 1,
#          ('dramatically', 'dramaticly'): 1,
#          ('dramaticly', 'drunkenness'): 1,
#          ('drunkenness', 'drunkeness'): 1,
#          ('drunkeness', 'due'): 1,
#          ('due', 'dur'): 1,
#          ('dur', 'during'): 1,
#          ('during', 'duren'): 1,
#          ('duren', 'dynamic'): 1,
#          ('dynamic', 'dymatic'): 1,
#          ('dymatic', 'dynaic'): 1,
#          ('dynaic', 'ecstasy'): 1,
#          ('ecstasy', 'ecstacy'): 1,
#          ('ecstacy', 'efficacy'): 1,
#          ('efficacy', 'efficity'): 1,
#          ('efficity', 'efficient'): 1,
#          ('efficient', 'efficat'): 1,
#          ('efficat', 'efforts'): 1,
#          ('efforts', 'effots'): 1,
#          ('effots', 'elegant'): 1,
#          ('elegant', 'elagent'): 1,
#          ('elagent', 'elligit'): 1,
#          ('elligit', 'embarrass'): 1,
#          ('embarrass', 'embarass'): 1,
#          ('embarass', 'embaress'): 1,
#          ('embaress', 'embarrassment'): 1,
#          ('embarrassment', 'embarassment'): 1,
#          ('embarassment', 'embed'): 1,
#          ('embed', 'imbed'): 1,
#          ('imbed', 'encapsulation'): 1,
#          ('encapsulation', 'encapsualtion'): 1,
#          ('encapsualtion', 'encyclopedia'): 1,
#          ('encyclopedia', 'encyclapidia'): 1,
#          ('encyclapidia', 'encyclopia'): 1,
#          ('encyclopia', 'engine'): 1,
#          ('engine', 'engins'): 1,
#          ('engins', 'enhance'): 1,
#          ('enhance', 'enhence'): 1,
#          ('enhence', 'enlightenment'): 1,
#          ('enlightenment', 'enligtment'): 1,
#          ('enligtment', 'ennui'): 1,
#          ('ennui', 'ennuui'): 1,
#          ('ennuui', 'enough'): 1,
#          ('enough', 'enought'): 1,
#          ('enought', 'environment'): 1,
#          ('environment', 'enviroment'): 1,
#          ('enviroment', 'environmental'): 1,
#          ('environmental', 'envireminakl'): 1,
#          ('envireminakl', 'invermeantial'): 1,
#          ('invermeantial', 'epitome'): 1,
#          ('epitome', 'epitomy'): 1,
#          ('epitomy', 'error'): 1,
#          ('error', 'errara'): 1,
#          ('errara', 'erro'): 1,
#          ('erro', 'espresso'): 1,
#          ('espresso', 'expresso'): 1,
#          ('expresso', 'etiology'): 1,
#          ('etiology', 'eitiology'): 1,
#          ('eitiology', 'evaluation'): 1,
#          ('evaluation', 'evaualtion'): 1,
#          ('evaualtion', 'eventually'): 1,
#          ('eventually', 'evtually'): 1,
#          ('evtually', 'everything'): 1,
#          ('everything', 'evething'): 1,
#          ('evething', 'exceed'): 1,
#          ('exceed', 'excede'): 1,
#          ('excede', 'except'): 1,
#          ('except', 'excpt'): 1,
#          ('excpt', 'execution'): 1,
#          ('execution', 'excution'): 1,
#          ('excution', 'exercise'): 1,
#          ('exercise', 'excercise'): 1,
#          ('excercise', 'exhilaration'): 1,
#          ('exhilaration', 'exhileration'): 1,
#          ('exhileration', 'existence'): 1,
#          ('existence', 'egsistence'): 1,
#          ('egsistence', 'existance'): 1,
#          ('existance', 'expedient'): 1,
#          ('expedient', 'exspidient'): 1,
#          ('exspidient', 'explicitly'): 1,
#          ('explicitly', 'expleyly'): 1,
#          ('expleyly', 'explity'): 1,
#          ('explity', 'extensions'): 1,
#          ('extensions', 'extions'): 1,
#          ('extions', 'factorization'): 1,
#          ('factorization', 'factontion'): 1,
#          ('factontion', 'failure'): 1,
#          ('failure', 'failer'): 1,
#          ('failer', 'fantasia'): 1,
#          ('fantasia', 'phantasia'): 1,
#          ('phantasia', 'fantasy'): 1,
#          ('fantasy', 'famdasy'): 1,
#          ('famdasy', 'favor'): 1,
#          ('favor', 'faver'): 1,
#          ('faver', 'favour'): 1,
#          ('favour', 'faver'): 1,
#          ('faver', 'fax'): 1,
#          ('fax', 'faxe'): 1,
#          ('faxe', 'festival'): 1,
#          ('festival', 'fistival'): 1,
#          ('fistival', 'fiery'): 1,
#          ('fiery', 'firey'): 1,
#          ('firey', 'flattering'): 1,
#          ('flattering', 'flatterring'): 1,
#          ('flatterring', 'flux'): 1,
#          ('flux', 'fluk'): 1,
#          ('fluk', 'flukse'): 1,
#          ('flukse', 'foresee'): 1,
#          ('foresee', 'forsee'): 1,
#          ('forsee', 'frustrating'): 1,
#          ('frustrating', 'frustartaion'): 1,
#          ('frustartaion', 'function'): 1,
#          ('function', 'fuction'): 1,
#          ('fuction', 'generally'): 1,
#          ('generally', 'generly'): 1,
#          ('generly', 'gotten'): 1,
#          ('gotten', 'gotton'): 1,
#          ('gotton', 'government'): 1,
#          ('government', 'goberment'): 1,
#          ('goberment', 'gobernement'): 1,
#          ('gobernement', 'gobernment'): 1,
#          ('gobernment', 'graceful'): 1,
#          ('graceful', 'gracefull'): 1,
#          ('gracefull', 'gradually'): 1,
#          ('gradually', 'gradualy'): 1,
#          ('gradualy', 'grammar'): 1,
#          ('grammar', 'grammer'): 1,
#          ('grammer', 'guard'): 1,
#          ('guard', 'gaurd'): 1,
#          ('gaurd', 'guts'): 1,
#          ('guts', 'futs'): 1,
#          ('futs', 'happily'): 1,
#          ('happily', 'hapily'): 1,
#          ('hapily', 'harass'): 1,
#          ('harass', 'harrass'): 1,
#          ('harrass', 'have'): 1,
#          ('have', 'havne'): 1,
#          ('havne', 'height'): 1,
#          ('height', 'heighth'): 1,
#          ('heighth', 'hello'): 1,
#          ('hello', 'hallo'): 1,
#          ('hallo', 'helo'): 1,
#          ('helo', 'herlo'): 1,
#          ('herlo', 'help'): 1,
#          ('help', 'heellp'): 1,
#          ('heellp', 'hellp'): 1,
#          ('hellp', 'hlp'): 1,
#          ('hlp', 'higher'): 1,
#          ('higher', 'higer'): 1,
#          ('higer', 'hippopotamus'): 1,
#          ('hippopotamus', 'hippopotamous'): 1,
#          ('hippopotamous', 'horse'): 1,
#          ('horse', 'hourse'): 1,
#          ('hourse', 'housing'): 1,
#          ('housing', 'houssing'): 1,
#          ('houssing', 'however'): 1,
#          ('however', 'howaver'): 1,
#          ('howaver', 'howver'): 1,
#          ('howver', 'humanity'): 1,
#          ('humanity', 'humaniti'): 1,
#          ('humaniti', 'hyphen'): 1,
#          ('hyphen', 'hifin'): 1,
#          ('hifin', 'hifine'): 1,
#          ('hifine', 'hiphine'): 1,
#          ('hiphine', 'hyfin'): 1,
#          ('hyfin', 'hypothesis'): 1,
#          ('hypothesis', 'hypotathes'): 1,
#          ('hypotathes', 'hypotathese'): 1,
#          ('hypotathese', 'hysterical'): 1,
#          ('hysterical', 'hystrical'): 1,
#          ('hystrical', 'illegitimate'): 1,
#          ('illegitimate', 'illegitament'): 1,
#          ('illegitament', 'immanent'): 1,
#          ('immanent', 'immenant'): 1,
#          ('immenant', 'immediately'): 1,
#          ('immediately', 'imediaetly'): 1,
#          ('imediaetly', 'implements'): 1,
#          ('implements', 'implemtes'): 1,
#          ('implemtes', 'in_case'): 1,
#          ('in_case', 'incase'): 1,
#          ('incase', 'in_depth'): 1,
#          ('in_depth', 'indepth'): 1,
#          ('indepth', 'in_fact'): 1,
#          ('in_fact', 'infact'): 1,
#          ('infact', 'inadvertent'): 1,
#          ('inadvertent', 'inadvertant'): 1,
#          ('inadvertant', 'incomplete'): 1,
#          ('incomplete', 'incompleet'): 1,
#          ('incompleet', 'incomplot'): 1,
#          ('incomplot', 'inconvenience'): 1,
#          ('inconvenience', 'inconvience'): 1,
#          ('inconvience', 'inconvenient'): 1,
#          ('inconvenient', 'inconvenant'): 1,
#          ('inconvenant', 'indent'): 1,
#          ('indent', 'ident'): 1,
#          ('ident', 'independent'): 1,
#          ('independent', 'independant'): 1,
#          ('independant', 'independenent'): 1,
#          ('independenent', 'indepnends'): 1,
#          ('indepnends', 'indispensable'): 1,
#          ('indispensable', 'indispensible'): 1,
#          ('indispensible', 'inefficient'): 1,
#          ('inefficient', 'inefficite'): 1,
#          ('inefficite', 'infamy'): 1,
#          ('infamy', 'imfamy'): 1,
#          ('imfamy', 'influential'): 1,
#          ('influential', 'influencial'): 1,
#          ('influencial', 'initial'): 1,
#          ('initial', 'inital'): 1,
#          ('inital', 'initialized'): 1,
#          ('initialized', 'initinized'): 1,
#          ('initinized', 'initized'): 1,
#          ('initized', 'inoculate'): 1,
#          ('inoculate', 'innoculate'): 1,
#          ('innoculate', 'insidious'): 1,
#          ('insidious', 'incedious'): 1,
#          ('incedious', 'insistent'): 1,
#          ('insistent', 'insistant'): 1,
#          ('insistant', 'insistenet'): 1,
#          ('insistenet', 'installation'): 1,
#          ('installation', 'instulation'): 1,
#          ('instulation', 'intelligent'): 1,
#          ('intelligent', 'intealignt'): 1,
#          ('intealignt', 'intejilent'): 1,
#          ('intejilent', 'intelegent'): 1,
#          ('intelegent', 'intelegnent'): 1,
#          ('intelegnent', 'intelejent'): 1,
#          ('intelejent', 'inteligent'): 1,
#          ('inteligent', 'intelignt'): 1,
#          ('intelignt', 'intellagant'): 1,
#          ('intellagant', 'intellegent'): 1,
#          ('intellegent', 'intellegint'): 1,
#          ('intellegint', 'intellgnt'): 1,
#          ('intellgnt', 'interested'): 1,
#          ('interested', 'intertes'): 1,
#          ('intertes', 'intertesd'): 1,
#          ('intertesd', 'interface'): 1,
#          ('interface', 'inerface'): 1,
#          ('inerface', 'international'): 1,
#          ('international', 'internation'): 1,
#          ('internation', 'interpret'): 1,
#          ('interpret', 'interpretate'): 1,
#          ('interpretate', 'interpreter'): 1,
#          ('interpreter', 'interpretter'): 1,
#          ('interpretter', 'inventions'): 1,
#          ('inventions', 'enventions'): 1,
#          ('enventions', 'irresistible'): 1,
#          ('irresistible', 'irresistable'): 1,
#          ('irresistable', 'irritable'): 1,
#          ('irritable', 'irritible'): 1,
#          ('irritible', 'isotope'): 1,
#          ('isotope', 'isotrop'): 1,
#          ('isotrop', 'iterate'): 1,
#          ('iterate', 'interate'): 1,
#          ('interate', 'john'): 1,
#          ('john', 'johhn'): 1,
#          ('johhn', 'judgement'): 1,
#          ('judgement', 'judgment'): 1,
#          ('judgment', 'judgment'): 1,
#          ('judgment', 'judgement'): 1,
#          ('judgement', 'kilometer'): 1,
#          ('kilometer', 'lilometer'): 1,
#          ('lilometer', 'kilometre'): 1,
#          ('kilometre', 'lilometer'): 1,
#          ('lilometer', 'kipper'): 1,
#          ('kipper', 'kippur'): 1,
#          ('kippur', 'knowing'): 1,
#          ('knowing', 'knawing'): 1,
#          ('knawing', 'laser'): 1,
#          ('laser', 'luser'): 1,
#          ('luser', 'latest'): 1,
#          ('latest', 'latext'): 1,
#          ('latext', 'layer'): 1,
#          ('layer', 'lloyer'): 1,
#          ('lloyer', 'leave'): 1,
#          ('leave', 'leasve'): 1,
#          ('leasve', 'leisure'): 1,
#          ('leisure', 'lesure'): 1,
#          ('lesure', 'lesion'): 1,
#          ('lesion', 'liasion'): 1,
#          ('liasion', 'liaison'): 1,
#          ('liaison', 'liason'): 1,
#          ('liason', 'library'): 1,
#          ('library', 'libary'): 1,
#          ('libary', 'likely'): 1,
#          ('likely', 'likly'): 1,
#          ('likly', 'liquefy'): 1,
#          ('liquefy', 'liquify'): 1,
#          ('liquify', 'losing'): 1,
#          ('losing', 'lossing'): 1,
#          ('lossing', 'madness'): 1,
#          ('madness', 'maddness'): 1,
#          ('maddness', 'maintenance'): 1,
#          ('maintenance', 'maintanence'): 1,
#          ('maintanence', 'majority'): 1,
#          ('majority', 'majaerly'): 1,
#          ('majaerly', 'majoraly'): 1,
#          ('majoraly', 'marshal'): 1,
#          ('marshal', 'marshall'): 1,
#          ('marshall', 'masks'): 1,
#          ('masks', 'maks'): 1,
#          ('maks', 'maximum'): 1,
#          ('maximum', 'maxium'): 1,
#          ('maxium', 'media'): 1,
#          ('media', 'midia'): 1,
#          ('midia', 'memento'): 1,
#          ('memento', 'momento'): 1,
#          ('momento', 'memory'): 1,
#          ('memory', 'meory'): 1,
#          ('meory', 'metaphysical'): 1,
#          ('metaphysical', 'pataphysical'): 1,
#          ('pataphysical', 'mike'): 1,
#          ('mike', 'mic'): 1,
#          ('mic', 'millennium'): 1,
#          ('millennium', 'millenium'): 1,
#          ('millenium', 'minimum'): 1,
#          ('minimum', 'minum'): 1,
#          ('minum', 'minuscule'): 1,
#          ('minuscule', 'miniscule'): 1,
#          ('miniscule', 'miscellaneous'): 1,
#          ('miscellaneous', 'misilous'): 1,
#          ('misilous', 'mischievous'): 1,
#          ('mischievous', 'mischievious'): 1,
#          ('mischievious', 'monkey'): 1,
#          ('monkey', 'minkay'): 1,
#          ('minkay', 'monkay'): 1,
#          ('monkay', 'more'): 1,
#          ('more', 'mroe'): 1,
#          ('mroe', 'mosaic'): 1,
#          ('mosaic', 'mosaik'): 1,
#          ('mosaik', 'most_likely'): 1,
#          ('most_likely', 'mostlikely'): 1,
#          ('mostlikely', 'mouser'): 1,
#          ('mouser', 'mousr'): 1,
#          ('mousr', 'moving'): 1,
#          ('moving', 'oving'): 1,
#          ('oving', 'naive'): 1,
#          ('naive', 'nieve'): 1,
#          ('nieve', 'necessary'): 1,
#          ('necessary', 'neccessary'): 1,
#          ('neccessary', 'necesary'): 1,
#          ('necesary', 'necesser'): 1,
#          ('necesser', 'neighbor'): 1,
#          ('neighbor', 'neighbour'): 1,
#          ('neighbour', 'neighbour'): 1,
#          ('neighbour', 'neighbor'): 1,
#          ('neighbor', 'nickelodeon'): 1,
#          ('nickelodeon', 'nickleodeon'): 1,
#          ('nickleodeon', 'niece'): 1,
#          ('niece', 'neice'): 1,
#          ('neice', 'no_one'): 1,
#          ('no_one', 'noone'): 1,
#          ('noone', 'not_in'): 1,
#          ('not_in', 'notin'): 1,
#          ('notin', 'noticeably'): 1,
#          ('noticeably', 'noticably'): 1,
#          ('noticably', 'nuzzled'): 1,
#          ('nuzzled', 'nozled'): 1,
#          ('nozled', 'obfuscate'): 1,
#          ('obfuscate', 'obsfuscate'): 1,
#          ('obsfuscate', 'objects'): 1,
#          ('objects', 'objectsion'): 1,
#          ('objectsion', 'occasion'): 1,
#          ('occasion', 'ocassion'): 1,
#          ('ocassion', 'occasionally'): 1,
#          ('occasionally', 'accosinly'): 1,
#          ('accosinly', 'occusionaly'): 1,
#          ('occusionaly', 'occupied'): 1,
#          ('occupied', 'occuppied'): 1,
#          ('occuppied', 'occurrence'): 1,
#          ('occurrence', 'occurence'): 1,
#          ('occurence', 'octogenarian'): 1,
#          ('octogenarian', 'octagenarian'): 1,
#          ('octagenarian', 'old'): 1,
#          ('old', 'olf'): 1,
#          ('olf', 'opossum'): 1,
#          ('opossum', 'opposim'): 1,
#          ('opposim', 'organize'): 1,
#          ('organize', 'organise'): 1,
#          ('organise', 'organiz'): 1,
#          ('organiz', 'orient'): 1,
#          ('orient', 'orientate'): 1,
#          ('orientate', 'oscilloscope'): 1,
#          ('oscilloscope', 'oscilascope'): 1,
#          ('oscilascope', 'parameter'): 1,
#          ('parameter', 'parametic'): 1,
#          ('parametic', 'parameters'): 1,
#          ('parameters', 'paramers'): 1,
#          ('paramers', 'paranets'): 1,
#          ('paranets', 'particular'): 1,
#          ('particular', 'partrucal'): 1,
#          ('partrucal', 'pattern'): 1,
#          ('pattern', 'patten'): 1,
#          ('patten', 'peremptory'): 1,
#          ('peremptory', 'preemptory'): 1,
#          ('preemptory', 'permissible'): 1,
#          ('permissible', 'permissable'): 1,
#          ('permissable', 'permission'): 1,
#          ('permission', 'permition'): 1,
#          ('permition', 'permissive'): 1,
#          ('permissive', 'permmasivie'): 1,
#          ('permmasivie', 'phenomenal'): 1,
#          ('phenomenal', 'phenominal'): 1,
#          ('phenominal', 'phone'): 1,
#          ('phone', 'fone'): 1,
#          ('fone', 'phonetic'): 1,
#          ('phonetic', 'funetik'): 1,
#          ('funetik', 'picturesque'): 1,
#          ('picturesque', 'picaresque'): 1,
#          ('picaresque', 'playwright'): 1,
#          ('playwright', 'playwrite'): 1,
#          ('playwrite', 'police'): 1,
#          ('police', 'pollice'): 1,
#          ('pollice', 'politic'): 1,
#          ('politic', 'politict'): 1,
#          ('politict', 'politician'): 1,
#          ('politician', 'polation'): 1,
#          ('polation', 'polygamy'): 1,
#          ('polygamy', 'poligamy'): 1,
#          ('poligamy', 'polypropylene'): 1,
#          ('polypropylene', 'polypropalene'): 1,
#          ('polypropalene', 'portray'): 1,
#          ('portray', 'protray'): 1,
#          ('protray', 'possible'): 1,
#          ('possible', 'possable'): 1,
#          ('possable', 'practical'): 1,
#          ('practical', 'practicle'): 1,
#          ('practicle', 'pragmatism'): 1,
#          ('pragmatism', 'pragmaticism'): 1,
#          ('pragmaticism', 'preceding'): 1,
#          ('preceding', 'preceeding'): 1,
#          ('preceeding', 'precision'): 1,
#          ('precision', 'precion'): 1,
#          ('precion', 'precios'): 1,
#          ('precios', 'prefixed'): 1,
#          ('prefixed', 'prefixt'): 1,
#          ('prefixt', 'prefixes'): 1,
#          ('prefixes', 'prefices'): 1,
#          ('prefices', 'prerogative'): 1,
#          ('prerogative', 'perogative'): 1,
#          ('perogative', 'privilege'): 1,
#          ('privilege', 'privielage'): 1,
#          ('privielage', 'priviledge'): 1,
#          ('priviledge', 'problematic'): 1,
#          ('problematic', 'proplematic'): 1,
#          ('proplematic', 'procedures'): 1,
#          ('procedures', 'proceedures'): 1,
#          ('proceedures', 'pronunciation'): 1,
#          ('pronunciation', 'pronensiation'): 1,
#          ('pronensiation', 'pronisation'): 1,
#          ('pronisation', 'pronounciation'): 1,
#          ('pronounciation', 'properly'): 1,
#          ('properly', 'properally'): 1,
#          ('properally', 'psychologist'): 1,
#          ('psychologist', 'pscolgst'): 1,
#          ('pscolgst', 'psicolagest'): 1,
#          ('psicolagest', 'psycolagest'): 1,
#          ('psycolagest', 'sicolagest'): 1,
#          ('sicolagest', 'pursue'): 1,
#          ('pursue', 'persue'): 1,
#          ('persue', 'presue'): 1,
#          ('presue', 'pursued'): 1,
#          ('pursued', 'presued'): 1,
#          ('presued', 'quiz'): 1,
#          ('quiz', 'quoz'): 1,
#          ('quoz', 'raccoon'): 1,
#          ('raccoon', 'reccona'): 1,
#          ('reccona', 'radius'): 1,
#          ('radius', 'radious'): 1,
#          ('radious', 'rampantly'): 1,
#          ('rampantly', 'ramplily'): 1,
#          ('ramplily', 'rank'): 1,
#          ('rank', 'wrank'): 1,
#          ('wrank', 'receive'): 1,
#          ('receive', 'recieve'): 1,
#          ('recieve', 'recognize'): 1,
#          ('recognize', 'reconise'): 1,
#          ('reconise', 'recommend'): 1,
#          ('recommend', 'reccomend'): 1,
#          ('reccomend', 'rectangle'): 1,
#          ('rectangle', 'rectangeles'): 1,
#          ('rectangeles', 'recurring'): 1,
#          ('recurring', 'reoccurring'): 1,
#          ('reoccurring', 'redesign'): 1,
#          ('redesign', 'redign'): 1,
#          ('redign', 'regardless'): 1,
#          ('regardless', 'irregardless'): 1,
#          ('irregardless', 'repetition'): 1,
#          ('repetition', 'repitition'): 1,
#          ('repitition', 'replacement'): 1,
#          ('replacement', 'replasments'): 1,
#          ('replasments', 'resemblance'): 1,
#          ('resemblance', 'reseblence'): 1,
#          ('reseblence', 'respect'): 1,
#          ('respect', 'respct'): 1,
#          ('respct', 'respectfully'): 1,
#          ('respectfully', 'respecally'): 1,
#          ('respecally', 'responsible'): 1,
#          ('responsible', 'reposable'): 1,
#          ('reposable', 'room'): 1,
#          ('room', 'roon'): 1,
#          ('roon', 'roughly'): 1,
#          ('roughly', 'rought'): 1,
#          ('rought', 'rudimentary'): 1,
#          ('rudimentary', 'rudemtry'): 1,
#          ('rudemtry', 'running'): 1,
#          ('running', 'runnung'): 1,
#          ('runnung', 'sacrilegious'): 1,
#          ('sacrilegious', 'sacreligious'): 1,
#          ('sacreligious', 'safely'): 1,
#          ('safely', 'saftly'): 1,
#          ('saftly', 'salute'): 1,
#          ('salute', 'salut'): 1,
#          ('salut', 'satisfy'): 1,
#          ('satisfy', 'satifly'): 1,
#          ('satifly', 'scrabble'): 1,
#          ('scrabble', 'scrabdle'): 1,
#          ('scrabdle', 'section'): 1,
#          ('section', 'secion'): 1,
#          ('secion', 'segments'): 1,
#          ('segments', 'segements'): 1,
#          ('segements', 'seize'): 1,
#          ('seize', 'sieze'): 1,
#          ('sieze', 'sense'): 1,
#          ('sense', 'sence'): 1,
#          ('sence', 'separate'): 1,
#          ('separate', 'seperate'): 1,
#          ('seperate', 'several'): 1,
#          ('several', 'seferal'): 1,
#          ('seferal', 'sherbet'): 1,
#          ('sherbet', 'sherbert'): 1,
#          ('sherbert', 'signal'): 1,
#          ('signal', 'singal'): 1,
#          ('singal', 'simplicity'): 1,
#          ('simplicity', 'cimplicity'): 1,
#          ('cimplicity', 'simpfilty'): 1,
#          ('simpfilty', 'simply'): 1,
#          ('simply', 'simplye'): 1,
#          ('simplye', 'site'): 1,
#          ('site', 'sitte'): 1,
#          ('sitte', 'situation'): 1,
#          ('situation', 'situration'): 1,
#          ('situration', 'smile'): 1,
#          ('smile', 'smil'): 1,
#          ('smil', 'sneaked'): 1,
#          ('sneaked', 'snuck'): 1,
#          ('snuck', 'sometimes'): 1,
#          ('sometimes', 'sometmes'): 1,
#          ('sometmes', 'sonic'): 1,
#          ('sonic', 'soonec'): 1,
#          ('soonec', 'specifically'): 1,
#          ('specifically', 'specificialy'): 1,
#          ('specificialy', 'spell'): 1,
#          ('spell', 'spel'): 1,
#          ('spel', 'spoke'): 1,
#          ('spoke', 'spoak'): 1,
#          ('spoak', 'sponsored'): 1,
#          ('sponsored', 'sponsered'): 1,
#          ('sponsered', 'steering'): 1,
#          ('steering', 'stering'): 1,
#          ('stering', 'stomach'): 1,
#          ('stomach', 'stumach'): 1,
#          ('stumach', 'straitjacket'): 1,
#          ('straitjacket', 'straightjacket'): 1,
#          ('straightjacket', 'student'): 1,
#          ('student', 'stutent'): 1,
#          ('stutent', 'style_guide'): 1,
#          ('style_guide', 'styleguide'): 1,
#          ('styleguide', 'subpoena'): 1,
#          ('subpoena', 'subpena'): 1,
#          ('subpena', 'subscribed'): 1,
#          ('subscribed', 'subjecribed'): 1,
#          ('subjecribed', 'substitutions'): 1,
#          ('substitutions', 'subisitions'): 1,
#          ('subisitions', 'substations'): 1,
#          ('substations', 'sugar'): 1,
#          ('sugar', 'suger'): 1,
#          ('suger', 'superfluous'): 1,
#          ('superfluous', 'superfulous'): 1,
#          ('superfulous', 'supersede'): 1,
#          ('supersede', 'supercede'): 1,
#          ('supercede', 'swimwear'): 1,
#          ('swimwear', 'swim_wear'): 1,
#          ('swim_wear', 'sylph'): 1,
#          ('sylph', 'slyph'): 1,
#          ('slyph', 'synchronization'): 1,
#          ('synchronization', 'syncorization'): 1,
#          ('syncorization', 'tattoos'): 1,
#          ('tattoos', 'tattos'): 1,
#          ('tattos', 'team'): 1,
#          ('team', 'tem'): 1,
#          ('tem', 'technically'): 1,
#          ('technically', 'techniquely'): 1,
#          ('techniquely', 'test'): 1,
#          ('test', 'tesst'): 1,
#          ('tesst', 'ttest'): 1,
#          ('ttest', 'tests'): 1,
#          ('tests', 'tets'): 1,
#          ('tets', 'than_or'): 1,
#          ('than_or', 'thanot'): 1,
#          ('thanot', 'that'): 1,
#          ('that', 'taht'): 1,
#          ('taht', 'the'): 1,
#          ('the', 'teh'): 1,
#          ('teh', 'thw'): 1,
#          ('thw', 'themselves'): 1,
#          ('themselves', 'theirselves'): 1,
#          ('theirselves', 'theoretical'): 1,
#          ('theoretical', 'teridical'): 1,
#          ('teridical', 'theridically'): 1,
#          ('theridically', 'theoretically'): 1,
#          ('theoretically', 'thredically'): 1,
#          ('thredically', 'this'): 1,
#          ('this', 'ths'): 1,
#          ('ths', 'throughout'): 1,
#          ('throughout', 'thruout'): 1,
#          ('thruout', 'titillate'): 1,
#          ('titillate', 'titalate'): 1,
#          ('titalate', 'tomorrow'): 1,
#          ('tomorrow', 'tommorrow'): 1,
#          ('tommorrow', 'tomorow'): 1,
#          ('tomorow', 'tough'): 1,
#          ('tough', 'taff'): 1,
#          ('taff', 'tragedy'): 1,
#          ('tragedy', 'tradegy'): 1,
#          ('tradegy', 'trouble'): 1,
#          ('trouble', 'trubbel'): 1,
#          ('trubbel', 'tunnel_like'): 1,
#          ('tunnel_like', 'tunnellike'): 1,
#          ('tunnellike', 'turned'): 1,
#          ('turned', 'tured'): 1,
#          ('tured', 'two'): 1,
#          ('two', 'teo'): 1,
#          ('teo', 'tyranny'): 1,
#          ('tyranny', 'tyrrany'): 1,
#          ('tyrrany', 'unconscious'): 1,
#          ('unconscious', 'unconscience'): 1,
#          ('unconscience', 'unconstitutional'): 1,
#          ('unconstitutional', 'unconisitional'): 1,
#          ('unconisitional', 'under_ladder'): 1,
#          ('under_ladder', 'underladder'): 1,
#          ('underladder', 'unfortunately'): 1,
#          ('unfortunately', 'unformanlly'): 1,
#          ('unformanlly', 'unfortally'): 1,
#          ('unfortally', 'unfortunently'): 1,
#          ('unfortunently', 'unintelligible'): 1,
#          ('unintelligible', 'unentelegible'): 1,
#          ('unentelegible', 'unnatural'): 1,
#          ('unnatural', 'unatourral'): 1,
#          ('unatourral', 'unaturral'): 1,
#          ('unaturral', 'unnaturral'): 1,
#          ('unnaturral', 'up_cast'): 1,
#          ('up_cast', 'upcast'): 1,
#          ('upcast', 'uranium'): 1,
#          ('uranium', 'uranisium'): 1,
#          ('uranisium', 'utmost'): 1,
#          ('utmost', 'upmost'): 1,
#          ('upmost', 'version'): 1,
#          ('version', 'verison'): 1,
#          ('verison', 'vinaigrette'): 1,
#          ('vinaigrette', 'vinagarette'): 1,
#          ('vinagarette', 'volley'): 1,
#          ('volley', 'volye'): 1,
#          ('volye', 'voluntarism'): 1,
#          ('voluntarism', 'volunteerism'): 1,
#          ('volunteerism', 'voluptuous'): 1,
#          ('voluptuous', 'volumptuous'): 1,
#          ('volumptuous', 'wait'): 1,
#          ('wait', 'waite'): 1,
#          ('waite', 'want'): 1,
#          ('want', 'mant'): 1,
#          ('mant', 'ward'): 1,
#          ('ward', 'whard'): 1,
#          ('whard', 'warlord'): 1,
#          ('warlord', 'warloord'): 1,
#          ('warloord', 'wasting'): 1,
#          ('wasting', 'wadting'): 1,
#          ('wadting', 'weaken'): 1,
#          ('weaken', 'wicken'): 1,
#          ('wicken', 'weird'): 1,
#          ('weird', 'wierd'): 1,
#          ('wierd', 'what'): 1,
#          ('what', 'whaaat'): 1,
#          ('whaaat', 'wimp'): 1,
#          ('wimp', 'whimp'): 1,
#          ('whimp', 'won'): 1,
#          ('won', 't'): 1,
#          ('t', 'wan'): 1,
#          ('wan', 't'): 1,
#          ('t', 'writing'): 1,
#          ('writing', 'writting'): 1,
#          ('writting', 'yield'): 1,
#          ('yield', 'yeild'): 1,
#          ('yeild', 'your'): 1,
#          ('your', 'youe'): 1})

# %% [markdown]
# # Calculate the probabilities of all Candidates for a given word

# %%
def get_previous(word):
    words = get_all_words(corpus)
    previous = dict()
    for w in range(len(words)):
        previous[words[w]] = words[w-1]
    return previous[word]

# %%
get_previous('coaln')
# Out:
# 'colon'

# %%
def Bigram_prob(word):
    uni_lambda = 0.4
    bi_lambda = 0.6
    candidate_prob_all = dict()
    candidate_words = candidates(word)
    unigram_counts = get_counts(1)
    bigram_counts = get_counts(2)
    prev_word = get_previous(word)
    for w in candidate_words:
        unigram_prob = unigram_counts[(word,)]/len(unigram_counts)
        if bigram_counts[(prev_word,word)]!=0:
            bigram_prob = bigram_counts[(prev_word,word)]/unigram_counts[(prev_word),]
        else:
            bigram_prob = 0
        candidate_prob = (unigram_prob * uni_lambda)+(bigram_prob * bi_lambda)
        if candidate_prob != 0:
            candidate_prob_all[word] = candidate_prob
    return candidate_prob_all

# %%
Bigram_prob('coaln')
# Out:
# {'coaln': 0.6004132231404958}

# %%
def correct(word):
    correct_words = candidates(word)
    correct = dict()
    for err in correct_words:
        correct[err] = Bigram_prob(err)
    return correct

# %%
correct('colan')
# Out:
# {'colon': {'colon': 0.6004132231404958},
#  'coaln': {'coaln': 0.6004132231404958}}
